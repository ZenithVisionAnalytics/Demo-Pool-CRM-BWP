# %%
import psycopg2
import pandas as pd
from datetime import datetime, timedelta

# Database connection string
DATABASE_URL = (
    "postgresql://neondb_owner:npg_Ss2uYoZeUHt3"
    "@ep-misty-bread-a4s7ya4s-pooler.us-east-1.aws.neon.tech/"
    "neondb?sslmode=require&channel_binding=require"
)

def query_listings_in_bbox(min_lat, max_lat, min_lon, max_lon, days_back=365):
    """
    Query listings within a bounding box.
    
    Args:
        min_lat: Minimum latitude
        max_lat: Maximum latitude
        min_lon: Minimum longitude
        max_lon: Maximum longitude
        days_back: Days to look back for removed listings (default 30)
    
    Returns:
        tuple: (current_listings_df, removed_listings_df)
    """
    conn = psycopg2.connect(DATABASE_URL)
    
    try:
        # Query current listings
        current_query = """
            SELECT 
                mls_id,
                date_collected,
                description,
                bedrooms,
                bathrooms,
                size_sqft,
                stories,
                house_cat,
                price,
                address_number,
                street_name,
                full_street_name,
                locality,
                municipality,
                province_state,
                postal_code,
                pool_mentioned,
                lat,
                lon
            FROM listing
            WHERE lat BETWEEN %s AND %s
              AND lon BETWEEN %s AND %s
            ORDER BY date_collected DESC;
        """
        
        current_listings = pd.read_sql_query(
            current_query,
            conn,
            params=(min_lat, max_lat, min_lon, max_lon)
        )
        
        # Query recently removed listings from the listing_removal table
        cutoff_date = datetime.now() - timedelta(days=days_back)
        
        removed_query = """
            SELECT 
                l.mls_id,
                l.date_collected,
                l.description,
                l.bedrooms,
                l.bathrooms,
                l.size_sqft,
                l.stories,
                l.house_cat,
                l.price,
                l.address_number,
                l.street_name,
                l.full_street_name,
                l.locality,
                l.municipality,
                l.province_state,
                l.postal_code,
                l.pool_mentioned,
                l.lat,
                l.lon,
                r.removal_id,
                r.removal_date
            FROM listing_removal r
            JOIN listing l ON l.mls_id = r.mls_id
            WHERE r.removal_date >= %s
              AND l.lat BETWEEN %s AND %s
              AND l.lon BETWEEN %s AND %s
            ORDER BY r.removal_date DESC;
        """
        
        removed_listings = pd.read_sql_query(
            removed_query,
            conn,
            params=(cutoff_date, min_lat, max_lat, min_lon, max_lon)
        )
        
        return current_listings, removed_listings
        
    finally:
        conn.close()


# Example usage - adjust bounding box for your area of interest
# Toronto downtown area example
min_lat = 43.7
max_lat = 43.9
min_lon = -80.5
max_lon = -79.5

print(f"Querying listings in bounding box:")
print(f"  Latitude: {min_lat} to {max_lat}")
print(f"  Longitude: {min_lon} to {max_lon}")

current, removed = query_listings_in_bbox(min_lat, max_lat, min_lon, max_lon)

print(f"\nFound {len(current)} current listings")
print(f"Found {len(removed)} recently removed listings (last 365 days)")

# Display sample data
if not current.empty:
    print("\nSample current listings:")
    print(current[['mls_id', 'price', 'bedrooms', 'bathrooms', 'municipality', 'lat', 'lon']].head())

if not removed.empty:
    print("\nSample removed listings:")
    print(removed[['mls_id', 'price', 'bedrooms', 'bathrooms', 'municipality', 'lat', 'lon']].head())
# Out:
# Querying listings in bounding box:
#   Latitude: 43.7 to 43.9
#   Longitude: -80.5 to -79.5
# /tmp/ipykernel_403163/2311666625.py:57: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   current_listings = pd.read_sql_query(
# Found 1187 current listings
# Found 791 recently removed listings (last 365 days)
#
# Sample current listings:
#       mls_id      price bedrooms bathrooms  \
# 0  W12662194  2475000.0    4 + 2       6.0
# 1   W8399984   709990.0        2       3.0
# 2  W12370202   690000.0        3       2.0
# 3  W12444103   769990.0        3       3.0
# 4  W12032853        1.0     None      None
#
#                               municipality        lat        lon
# 0                    Caledon (Bolton West)  43.874474 -79.732867
# 1                                  Caledon  43.723726 -79.835253
# 2                  Brampton (Central Park)  43.724955 -79.730055
# 3  Brampton (Sandringham-Wellington North)  43.769673 -79.775242
# 4                    Caledon (Bolton West)  43.847798 -79.717054
#
# Sample removed listings:
#       mls_id      price bedrooms bathrooms                       municipality  \
# 0  W12641798   829000.0    3 + 2         3               Brampton (Southgate)
# 1  W12640508  1029900.0    3 + 2         4                            Caledon
# 2  W12639504   869869.0    3 + 2         4  Brampton (Sandringham-Wellington)
# 3  W12639346   749800.0    3 + 1         2          Brampton (Brampton North)
# 4  W12639152   699000.0    3 + 1         4         Brampton (Heart Lake West)
#
#          lat        lon
# 0  43.725994 -79.702095
# 1  43.751870 -79.843570
# 2  43.769110 -79.732631
# 3  43.700364 -79.758067
# 4  43.718760 -79.801410
# /tmp/ipykernel_403163/2311666625.py:97: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   removed_listings = pd.read_sql_query(

# %%
removed.head()
# Out:
#       mls_id                   date_collected  \
# 0  W12641798 2025-12-22 19:52:20.123294+00:00
# 1  W12640508 2025-12-22 19:52:20.123294+00:00
# 2  W12639504 2025-12-22 19:52:20.123294+00:00
# 3  W12639346 2025-12-22 19:52:20.123294+00:00
# 4  W12639152 2025-12-22 19:52:20.123294+00:00
#
#                                          description bedrooms bathrooms  \
# 0  Welcome to 10 Evesham Crescent, a well-loved a...    3 + 2         3
# 1  !!! Legal Finished 2-Bedrooms Basement Semi-De...    3 + 2         4
# 2  Welcome to this beautifully maintained 3 bedro...    3 + 2         4
# 3  ***RAISED BUNGALOW! SEPARATE ENTRANCE! EGRESS ...    3 + 1         2
# 4  Tucked away on a quiet, family-oriented cul-de...    3 + 1         4
#
#   size_sqft  stories house_cat      price  address_number  ...  \
# 0   1099.99      1.0     House   829000.0              10  ...
# 1   1499.99      2.0     House  1029900.0              26  ...
# 2   1099.99      2.0     House   869869.0              25  ...
# 3    699.99      1.0     House   749800.0              31  ...
# 4   1099.99      2.0     House   699000.0              13  ...
#
#                                     full_street_name                locality  \
# 0  10 EVESHAM CRESCENT|Brampton (Southgate), Onta...               Southgate
# 1        26 DEER RIDGE TRAIL|Caledon, Ontario L7C3Z6                    None
# 2  25 REVELSTOKE PLACE|Brampton (Sandringham-Well...  Sandringham-Wellington
# 3  31 BRISCO STREET|Brampton (Brampton North), On...          Brampton North
# 4  13 SOUTHWELL PLACE|Brampton (Heart Lake West),...         Heart Lake West
#
#                         municipality province_state postal_code  \
# 0               Brampton (Southgate)        Ontario      L6T3M3
# 1                            Caledon        Ontario      L7C3Z6
# 2  Brampton (Sandringham-Wellington)        Ontario      L6R3G3
# 3          Brampton (Brampton North)        Ontario      L6V1X1
# 365  A Great Opportunity to Own an Executive Freeho...        3       3.0
# 376  Welcome to 54 Locust Drive, a beautifully main...    2 + 2       3.0
# 380  Now is the time to get into your new home!!! T...    1 + 2       2.0
# 385  Welcome to this spacious 5-level backsplit, fe...    4 + 2       3.0
# 386  Elegant Adult Lifestyle Living In Gated Roseda...    2 + 1       3.0
# 399  Look NO further!! Don't miss this Gem in The N...    4 + 1       4.0
# 401  Gorgeous Brand New Bungaloft In Rosedale Villa...    2 + 1       3.0
# 423  Nestled In Brampton's Premier Adult-Lifestyle ...    2 + 2       3.0
# 424  Enjoy Luxurious Living in This Sun-Filled 2-Be...        2       3.0
# 431  Downsizing Made Easy!! This Beautifully Mainta...        2       2.0
# 462  Bright and spacious bungalow located in the ex...        2       3.0
# 468  Welcome to 29 Nickel Cres, Brampton Located on...        4       4.0
# 491  Welcome to 57 Banington Crescenta beautifully ...    4 + 3       4.0
# 494  Welcome to this stunning home located in a hig...    3 + 1       2.0
# 503  Bright + Functional Townhome in Prime Brampton...    3 + 1       2.0
# 515  An ideal opportunity for first-time buyers, gr...        3       2.0
#
#      size_sqft  stories        house_cat      price  address_number  ...  \
# 19     1099.99      2.0            House   699999.0              84  ...
# 49     2499.98      2.0            House  1099000.0              31  ...
# 62     1499.99      2.0            House   869975.0              41  ...
# 95     1099.99      1.0            House   874900.0              30  ...
# 124    1199.99      3.0  Row / Townhouse   559000.0               5  ...
# 125    1199.99      2.0  Row / Townhouse   560000.0            1020  ...
# 127    1199.99      2.0  Row / Townhouse   569999.0              69  ...
# 135     999.99      2.0  Row / Townhouse   599999.0              33  ...
# 139    1199.99      2.0  Row / Townhouse   669000.0              30  ...
# 156    1199.99      2.0  Row / Townhouse   650000.0              65  ...
# 157     999.99      3.0  Row / Townhouse   659000.0               9  ...
# 162     999.99      2.0  Row / Townhouse   669900.0             132  ...
# 171    1199.99      2.0  Row / Townhouse   685000.0              72  ...
# 183     999.99      1.0  Row / Townhouse   699000.0              67  ...
# 186    1099.99      3.0  Row / Townhouse   699000.0              13  ...
# 189    1399.99      1.5  Row / Townhouse   699900.0             123  ...
# 211    1399.99      2.0  Row / Townhouse   728888.0              32  ...
# 216    1799.98      3.0  Row / Townhouse   739000.0             216  ...
# 263    1399.99      1.0            House   774900.0              12  ...
# 282  1704.0000      2.0  Row / Townhouse   799900.0              68  ...
# 290    1799.98      2.0  Row / Townhouse   819000.0              35  ...
# 291    1099.99      NaN            House   819000.0              33  ...
# 294     699.99      NaN            House   820000.0             129  ...
# 296    1399.99      1.0  Row / Townhouse   824900.0              40  ...
# 302  1342.0000      1.0  Row / Townhouse   837800.0              17  ...
# 309    1199.99      1.0  Row / Townhouse   845000.0              13  ...
# 314    1099.99      2.0            House   849900.0              30  ...
# 320    1599.98      1.5  Row / Townhouse   849000.0              36  ...
# 334    1599.98      1.5  Row / Townhouse   849900.0              81  ...
# 342    1499.99      2.0  Row / Townhouse   850000.0              41  ...
# 352    1499.99      3.0  Row / Townhouse   865000.0              58  ...
# 355    1499.99      2.0  Row / Townhouse   868888.0              34  ...
# 361    1599.98      1.0            House   875000.0              10  ...
# 364    1099.99      2.0            House   879000.0               4  ...
# 365    1499.99      3.0  Row / Townhouse   879000.0              22  ...
# 376    1399.99      1.0            House   895000.0              54  ...
# 380    1099.99      1.0            House   898888.0             119  ...
# 385    1499.99      NaN            House   899000.0              52  ...
# 386    1599.98      1.5  Row / Townhouse   899000.0               6  ...
# 399    1999.98      2.0            House   899000.0              18  ...
# 401    1799.98      1.5  Row / Townhouse   899800.0              41  ...
# 423    1599.98      1.0            House   900000.0               7  ...
# 424    1999.98      1.5            House   902500.0              26  ...
# 431    1599.98      1.0            House   925000.0               3  ...
# 462    1399.99      1.0            House   975000.0               1  ...
# 468    1499.99      2.0            House   989000.0              29  ...
# 491    2499.98      2.0            House   999900.0              57  ...
# 494     699.99      1.0            House   999988.0              39  ...
# 503    1199.99      2.0  Row / Townhouse   429000.0             105  ...
# 515     999.99      2.0  Row / Townhouse   550000.0             105  ...
#
#                    locality                       municipality province_state  \
# 19                    Madoc                   Brampton (Madoc)        Ontario
# 49                     None                            Caledon        Ontario
# 62          Heart Lake West         Brampton (Heart Lake West)        Ontario
# 95   Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 124            Central Park            Brampton (Central Park)        Ontario
# 125               Northgate               Brampton (Northgate)        Ontario
# 127            Central Park            Brampton (Central Park)        Ontario
# 135            Central Park            Brampton (Central Park)        Ontario
# 139               Northgate               Brampton (Northgate)        Ontario
# 156               Northgate               Brampton (Northgate)        Ontario
# 157            Central Park            Brampton (Central Park)        Ontario
# 162            Central Park            Brampton (Central Park)        Ontario
# 171            Central Park            Brampton (Central Park)        Ontario
# 183  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 186                    None                            Caledon        Ontario
# 189  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 211            Central Park            Brampton (Central Park)        Ontario
# 216               Southgate               Brampton (Southgate)        Ontario
# 263  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 282                    None                           Brampton        Ontario
# 290  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 291               Southgate               Brampton (Southgate)        Ontario
# 294               Southgate               Brampton (Southgate)        Ontario
# 296  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 302                    None                           Brampton        Ontario
# 309  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 314            Central Park            Brampton (Central Park)        Ontario
# 320  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 334  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 342  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 352            Caledon East             Caledon (Caledon East)        Ontario
# 355                    None                            Caledon        Ontario
# 361  Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 364               Southgate               Brampton (Southgate)        Ontario
# 365            Caledon East             Caledon (Caledon East)        Ontario
# 376 2025-12-11 16:53:31.894697+00:00           34 - 54 locust drive
# 380 2025-12-11 16:53:31.894697+00:00           119 sundridge street
# 385 2025-12-11 16:53:31.894697+00:00           52 maplehurst square
# 386 2025-12-11 16:53:31.894697+00:00           45 - 6 amarillo road
# 399 2025-12-11 16:53:31.894697+00:00             18 mitchell avenue
# 401 2025-12-11 16:53:31.894697+00:00               41 overlea drive
# 423 2025-12-11 16:53:31.894697+00:00            7 powder mill court
# 424 2025-12-11 16:53:31.894697+00:00  39 - 26 clermiston crescent w
# 431 2025-12-11 16:53:31.894697+00:00                 3 tuscany lane
# 462 2025-12-11 16:53:31.894697+00:00                1 wellford gate
# 468 2025-12-11 16:53:31.894697+00:00             29 nickel crescent
# 491 2025-12-11 16:53:31.894697+00:00          57 banington crescent
# 494 2025-12-11 16:53:31.894697+00:00            39 flavian crescent
# 503 2025-12-11 16:53:31.894697+00:00        111 - 105 hansen road n
# 515 2025-12-11 16:53:31.894697+00:00         47 - 105 hansen road n
#
# [50 rows x 22 columns]

# %%
def drop_duplicates(df):
    #if street name contains letters and numbers, and they are the same (standardized to lower case) except for case, consider them duplicates and drop one of them.
    df['street_name_std'] = df['street_name'].str.lower()
    df_deduped = df.drop_duplicates(subset=['street_name_std'])
    return df_deduped

deduped_removed = drop_duplicates(removed_with_pool)
len(deduped_removed)
# Out:
# /tmp/ipykernel_403163/3631676531.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['street_name_std'] = df['street_name'].str.lower()
# 89

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker

# %%
DISTILLED_DB = "master_pool_db_distilled"
DISTILLED_URL = f"postgresql://james:147896@localhost/{DISTILLED_DB}"
engine_distilled = create_engine(DISTILLED_URL)

# %%
#list all tables
with engine_distilled.connect() as conn:
    result = conn.execute(text(
        "SELECT table_name FROM information_schema.tables WHERE table_schema='public';"
    ))
    tables = result.fetchall()
    print("Tables in distilled database:")
    for table in tables:
        print(table[0])
# Out:
# Tables in distilled database:
# geography_columns
# geometry_columns
# spatial_ref_sys
# project
# pool
# addresses

# %%
# first 10 rows of pool table
with engine_distilled.connect() as conn:
    result = conn.execute(text(
        "SELECT * FROM addresses LIMIT 10;"
    ))
    
    # Get column names
    column_names = result.keys()
    print("Column names:", list(column_names))
    print()
    
    rows = result.fetchall()
    for row in rows:
        print(row)
# Out:
# Column names: ['address_id', 'address_number', 'address_number_suffix', 'lat', 'lon', 'footprint', 'street_predir', 'street_name', 'street_posttype', 'street_postdir', 'postal_code', 'full_street_name', 'locality', 'municipality', 'province_state', 'country', 'address_type', 'property_footprint', 'building_type', 'has_pool', 'pool_id', 'valuation']
#
# (1635, 289, '', 43.1355411, -80.76640809999999, None, '', 'Ingersoll Avenue', '', '', 'N4S 4W8', None, None, 'Woodstock', 'Ontario', 'Canada', None, '0103000020E61000000100000005000000B1039DFF0D3154C0D4DDD0EF56914540EE9AEB8F0B3154C0D4DDD0EF56914540EE9AEB8F0B3154C0A12DE7525C914540B1039DFF0D3154C0A12DE7525C914540B1039DFF0D3154C0D4DDD0EF56914540', None, True, 503, None)
# (1637, 185, '', 43.1351385, -80.76477899999999, None, '', 'Vansittart Avenue', '', '', 'N4S 6E7', None, None, 'Woodstock', 'Ontario', 'Canada', None, None, None, True, 509, None)
# (1643, 169, '', 43.135483, -80.7604313, None, '', 'Graham Street', '', '', 'N4S 6K2', None, None, 'Woodstock', 'Ontario', 'Canada', None, '0103000020E6100000010000000500000060127871AC3054C0CDCAAC9454914540DF84E74AA93054C0CDCAAC9454914540DF84E74AA93054C0E9CB77955A91454060127871AC3054C0E9CB77955A91454060127871AC3054C0CDCAAC9454914540', None, True, 515, None)
# (1644, 406, '', 43.1357368, -80.7613119, None, '', 'Ingersoll Avenue', '', '', 'N4S 4X5', None, None, 'Woodstock', 'Ontario', 'Canada', None, None, None, True, 3654, None)
# (1649, 140, '', 43.1345319, -80.75952509999999, None, '', 'Graham Street', '', '', 'N4S 6J9', None, None, 'Woodstock', 'Ontario', 'Canada', None, '0103000020E61000000100000005000000F7A9CF7A9D3054C097D8C6E935914540A52A12B89A3054C097D8C6E935914540A52A12B89A3054C0F4CE577F3A914540F7A9CF7A9D3054C0F4CE577F3A914540F7A9CF7A9D3054C097D8C6E935914540', None, True, 522, None)
# (1653, 65, '', 43.1359894, -80.735591, None, '', 'Clarke Street North', '', '', 'N4S 7M4', None, None, 'Woodstock', 'Ontario', 'Canada', None, '0103000020E61000000100000005000000D736209D152F54C00173E3CC65914540FD8E3C6B122F54C00173E3CC65914540FD8E3C6B122F54C0707841446A914540D736209D152F54C0707841446A914540D736209D152F54C00173E3CC65914540', None, True, 536, None)
# (1657, 245, '', 43.1377367, -80.7648931, None, '', 'Vansittart Avenue', '', '', 'N4S 6G1', None, None, 'Woodstock', 'Ontario', 'Canada', None, None, None, True, 1650, None)
# (1658, 251, '', 43.13776259999999, -80.7647842, None, '', 'Vansittart Avenue', '', '', 'N4S 6G1', None, None, 'Woodstock', 'Ontario', 'Canada', None, None, None, True, 550, None)
# (1660, 195, '', 43.1364539, -80.7623823, None, '', 'Light Street', '', '', 'N4S 6H6', None, None, 'Woodstock', 'Ontario', 'Canada', None, None, None, True, 552, None)
# (1663, 555, '', 43.1376328, -80.7558627, None, '', 'Grant Street', '', '', 'N4S 4Z1', None, None, 'Woodstock', 'Ontario', 'Canada', None, '0103000020E6100000010000000500000063A4CD27613054C0BD218D0A9C9145401DFE3FF35E3054C0BD218D0A9C9145401DFE3FF35E3054C0A2B9A9DC9F91454063A4CD27613054C0A2B9A9DC9F91454063A4CD27613054C0BD218D0A9C914540', None, True, 559, None)

# %%
# Query addresses in the distilled database within the bounding box and return as DataFrame
with engine_distilled.connect() as conn:
    addresses_df = pd.read_sql_query(
        text("""
        SELECT *
        FROM addresses
        WHERE lat BETWEEN :min_lat AND :max_lat
          AND lon BETWEEN :min_lon AND :max_lon
        """),
        conn,
        params={
            'min_lat': min_lat,
            'max_lat': max_lat,
            'min_lon': min_lon,
            'max_lon': max_lon
        }
    )

print(f"Found {len(addresses_df)} addresses in distilled database within bounding box")
addresses_df.head()
# Out:
# Found 8506 addresses in distilled database within bounding box
#    address_id  address_number address_number_suffix        lat        lon  \
# 0        4482              21                        43.726380 -79.780435
# 1       15818             206                        43.871434 -79.738038
# 2       15822             126                        43.872057 -79.734604
# 3       16978              58                        43.883406 -79.736908
# 4       16981              62                        43.883261 -79.737134
#
#   footprint street_predir         street_name street_posttype street_postdir  \
# 0      None                Moorehead Crescent
# 1      None                Ridgewood Crescent
# 2      None                Ellwood Drive West
# 3      None                      Sherin Court
# 4      None                      Sherin Court
#
#    ... locality municipality province_state country address_type  \
# 0  ...     None     Brampton        Ontario  Canada         None
# 1  ...     None       Bolton        Ontario  Canada         None
# 2  ...     None       Bolton        Ontario  Canada         None
# 3  ...     None       Bolton        Ontario  Canada         None
# 4  ...     None       Bolton        Ontario  Canada         None
#
#   property_footprint building_type has_pool pool_id  valuation
# 0               None          None     True    4555       None
# 1               None          None     True   61356       None
# 2               None          None     True   61360       None
# 3               None          None     True   62022       None
# 4               None          None     True   62023       None
#
# [5 rows x 22 columns]

# %%
addresses_df['has_pool'].value_counts()
# Out:
# has_pool
# True    8506
# Name: count, dtype: int64

# %%
addresses_df['address_std'] = addresses_df['address_number'].astype(str) + ' ' + addresses_df['street_name'].str.lower()

# %%
deduped_removed.head()
# Out:
#         mls_id                   date_collected  \
# 19   W12645286 2025-12-22 19:52:20.123294+00:00
# 49   W12563634 2025-12-22 19:52:20.123294+00:00
# 62   W12630534 2026-01-15 18:03:47.242298+00:00
# 95   W12623186 2026-01-15 18:03:47.242298+00:00
# 124  W12283223 2026-01-15 18:03:47.242298+00:00
#
#                                            description bedrooms bathrooms  \
# 19   Location! Location! Location! Beautiful 4 Bedr...        4         2
# 49   First time on the market! Lovingly maintained ...        4         4
# 62   Discover this gorgeous 3-bedroom, 3-bath semi-...    3 + 1       4.0
# 95   Welcome to 30 Muzzo Dr., an impeccably maintai...    2 + 2       3.0
# 124  Welcome To Your New Home! Nothing To Do But Un...        3       2.0
#
#     size_sqft  stories        house_cat      price  address_number  ...  \
# 19    1099.99      2.0            House   699999.0              84  ...
# 49    2499.98      2.0            House  1099000.0              31  ...
# 62    1499.99      2.0            House   869975.0              41  ...
# 95    1099.99      1.0            House   874900.0              30  ...
# 124   1199.99      3.0  Row / Townhouse   559000.0               5  ...
#
#                    locality                       municipality province_state  \
# 19                    Madoc                   Brampton (Madoc)        Ontario
# 49                     None                            Caledon        Ontario
# 62          Heart Lake West         Brampton (Heart Lake West)        Ontario
# 95   Sandringham-Wellington  Brampton (Sandringham-Wellington)        Ontario
# 124            Central Park            Brampton (Central Park)        Ontario
#
#     postal_code pool_mentioned        lat        lon  removal_id  \
# 19       L6V2H7           True  43.705533 -79.754948        6276
# 49       L7C1B1           True  43.746076 -79.829204        6182
# 62       L6Z3V6           True  43.720008 -79.786467        6234
# 95       L6R3W8           True  43.746126 -79.783190        4855
# 124      L6S3K9           True  43.732252 -79.750714        1143
#
#                         removal_date           street_name_std
# 19  2026-01-15 03:07:41.259837+00:00      84 sutherland avenue
# 673  Welcome to this Spacious 2,300 sq. ft. Home in...    4 + 1       3.0
# 676  Welcome to Prestigious North Hill, Bolton!Stun...    3 + 1       2.0
# 683  Immaculate, fully renovated home on one of the...        3       2.0
# 688  This attractive and meticulously maintained 4-...        4       4.0
# 689  Client RemarksWelcome to this open concept bea...        4       3.0
# 692  Your pool dream home has arrived! Located in o...    4 + 1       4.0
# 693  Beautifully Upgraded Home in Prime Bolton Loca...        4       4.0
# 763  Absolutely stunning, fully remodelled 4+1 bedr...    4 + 1       4.0
#
#     size_sqft  stories        house_cat      price  address_number  ...  \
# 291   1099.99      NaN            House   819000.0              33  ...
# 314   1099.99      2.0            House   849900.0              30  ...
# 355   1499.99      2.0  Row / Townhouse   868888.0              34  ...
# 364   1099.99      2.0            House   879000.0               4  ...
# 380   1099.99      1.0            House   898888.0             119  ...
# 385   1499.99      NaN            House   899000.0              52  ...
# 494    699.99      1.0            House   999988.0              39  ...
# 586   1499.99      2.0  Row / Townhouse  1049900.0               4  ...
# 590   1499.99      1.5            House  1198000.0              88  ...
# 591   1499.99      NaN            House  1248000.0              47  ...
# 592   1499.99      NaN            House  1295000.0              28  ...
# 596   2499.98      2.0            House  1599900.0              25  ...
# 609   1999.98      2.0            House  1550000.0              40  ...
# 623   2499.98      2.0            House  1949900.0               7  ...
# 631   2999.97      2.0            House  2200000.0             179  ...
# 664   1099.99      2.0            House   969000.0             160  ...
# 673   1999.98      2.0            House   979000.0             427  ...
# 676   1099.99      1.0            House  1069900.0             100  ...
# 683   1499.99      NaN            House  1149000.0              26  ...
# 688   1999.98      2.0            House  1198888.0             417  ...
# 689   1999.98      2.0            House  1249000.0              73  ...
# 692   1999.98      2.0            House  1298880.0              36  ...
# 693   1999.98      2.0            House  1299000.0              11  ...
# 763   2499.98      2.0            House  1498000.0              44  ...
#
#             locality                municipality province_state postal_code  \
# 291        Southgate        Brampton (Southgate)        Ontario      L6T2C1
# 314     Central Park     Brampton (Central Park)        Ontario      L6S5B2
# 355             None                     Caledon        Ontario      L7C1B2
# 364        Southgate        Brampton (Southgate)        Ontario      L6T2A9
# 380        Snelgrove        Brampton (Snelgrove)        Ontario      L7A1J8
# 385  Heart Lake East  Brampton (Heart Lake East)        Ontario      L6Z1J6
# 494        Southgate        Brampton (Southgate)        Ontario      L6T3P2
# 586     Caledon East      Caledon (Caledon East)        Ontario      L7C3X2
# 590     Caledon East      Caledon (Caledon East)        Ontario      L7C0G8
# 591     Caledon East      Caledon (Caledon East)        Ontario      L7C1K8
# 592     Caledon East      Caledon (Caledon East)        Ontario      L7C1K8
# 596     Caledon East      Caledon (Caledon East)        Ontario      L7C3R6
# 609     Caledon East      Caledon (Caledon East)        Ontario      L7C1H6
# 623     Caledon East      Caledon (Caledon East)        Ontario      L7C1P6
# 631         Nobleton             King (Nobleton)        Ontario      L0G1N0
# 664      Bolton East       Caledon (Bolton East)        Ontario      L7E1Y8
# 673     Bolton North      Caledon (Bolton North)        Ontario      L7E1J4
# 676     Bolton North      Caledon (Bolton North)        Ontario      L7E3T7
